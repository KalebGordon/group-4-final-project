# %%
# Import dependencies
import pandas as pd
from pathlib import Path

# %%
# Read CSV
emissions_path = Path("emissions_table.csv")
emissions_df = pd.read_csv(emissions_path)

# %%
# Check Work
emissions_df
# Out:
#                  area                            item  \
# 0       New Caledonia  Emissions on agricultural land
# 1       New Caledonia  Emissions on agricultural land
# 2       New Caledonia  Emissions on agricultural land
# 3       New Caledonia  Emissions on agricultural land
# 4       New Caledonia  Emissions on agricultural land
# ...               ...                             ...
# 186131        Ireland                   Savanna fires
# 186132        Ireland                   Savanna fires
# 186133        Ireland                   Savanna fires
# 186134        Ireland                   Savanna fires
# 186135        Ireland                   Savanna fires
#
#                            emission_type      unit  year_2000  year_2001  \
# 0                        Emissions (CH4)  kilotons     7.6030     7.5770
# 1                        Emissions (N2O)  kilotons     0.2945     0.2932
# 2                        Emissions (CO2)  kilotons    63.4218    49.9497
# ...

# %%
emissions_df = emissions_df.drop(columns='unit')

# %%
emissions_df = emissions_df.loc[emissions_df['item'] == 'All sectors with LULUCF']

# %%
emissions_df = emissions_df.drop(columns='item')
emissions_df = emissions_df.drop(columns='emissions_key')

# %%
emissions_df
# Out:
#                  area                         emission_type    year_2000  \
# 91      New Caledonia                       Emissions (CH4)       7.5428
# 92      New Caledonia                       Emissions (N2O)       0.2900
# 93      New Caledonia                       Emissions (CO2)    -207.8877
# 94      New Caledonia      Emissions (CO2eq) from CH4 (AR5)     211.1987
# 95      New Caledonia      Emissions (CO2eq) from N2O (AR5)      76.8594
# ...               ...                                   ...          ...
# 186036           Iraq                       Emissions (CO2)   79402.6247
# 186037           Iraq  Emissions (CO2eq) from F-gases (AR5)      33.0397
# 186038           Iraq      Emissions (CO2eq) from CH4 (AR5)   67816.5538
# 186039           Iraq      Emissions (CO2eq) from N2O (AR5)    5005.8332
# 186040           Iraq               Emissions (CO2eq) (AR5)  152258.0513
#
#           year_2001    year_2002    year_2003    year_2004    year_2005  \
# ...

# %%
emissions_df = emissions_df.drop_duplicates(keep='first')
emissions_df
# Out:
#                                 area                     emission_type  \
# 91                     New Caledonia                   Emissions (CH4)
# 92                     New Caledonia                   Emissions (N2O)
# 93                     New Caledonia                   Emissions (CO2)
# 94                     New Caledonia  Emissions (CO2eq) from CH4 (AR5)
# 95                     New Caledonia  Emissions (CO2eq) from N2O (AR5)
# ...                              ...                               ...
# 38363  Netherlands Antilles (former)                   Emissions (N2O)
# 38364  Netherlands Antilles (former)                   Emissions (CO2)
# 38365  Netherlands Antilles (former)  Emissions (CO2eq) from CH4 (AR5)
# 38366  Netherlands Antilles (former)  Emissions (CO2eq) from N2O (AR5)
# 38367  Netherlands Antilles (former)           Emissions (CO2eq) (AR5)
#
#        year_2000  year_2001  year_2002  year_2003  year_2004  year_2005  \
# ...

# %%
years = [c for c in emissions_df if c.startswith('year_')]

# %%
emissions_pivot_df = emissions_df.melt(id_vars=['area', 'emission_type'], value_vars=years, var_name='year', value_name = 'emissions(kilotons)')

# %%
emissions_pivot_df = emissions_pivot_df.pivot_table(index=['area', 'year'], columns='emission_type', values='emissions(kilotons)').reset_index()
emissions_pivot_df
# Out:
# emission_type                            area       year  Emissions (CH4)  \
# 0                                 Afghanistan  year_2000         419.1023
# 1                                 Afghanistan  year_2001         371.2675
# 2                                 Afghanistan  year_2002         447.8971
# 3                                 Afghanistan  year_2003         463.6655
# 4                                 Afghanistan  year_2004         465.8062
# ...                                       ...        ...              ...
# 4174           Svalbard and Jan Mayen Islands  year_2016           0.0000
# 4175           Svalbard and Jan Mayen Islands  year_2017           0.0000
# 4176           Svalbard and Jan Mayen Islands  year_2018           0.0000
# 4177           Svalbard and Jan Mayen Islands  year_2019           0.0000
# 4178           Svalbard and Jan Mayen Islands  year_2020           0.0000
#
# emission_type  Emissions (CO2)  Emissions (CO2eq) (AR5)  \
# ...

# %%
emissions_pivot_df['year'] = emissions_pivot_df['year'].str.replace("year_", "")
emissions_pivot_df['year'] = emissions_pivot_df['year'].astype(int)

# %%
emissions_pivot_df.dtypes
# Out:
# emission_type
# area                                     object
# year                                      int32
# Emissions (CH4)                         float64
# Emissions (CO2)                         float64
# Emissions (CO2eq) (AR5)                 float64
# Emissions (CO2eq) from CH4 (AR5)        float64
# Emissions (CO2eq) from F-gases (AR5)    float64
# Emissions (CO2eq) from N2O (AR5)        float64
# Emissions (N2O)                         float64
# dtype: object

# %%
emissions_pivot_df
# Out:
# emission_type                            area  year  Emissions (CH4)  \
# 0                                 Afghanistan  2000         419.1023
# 1                                 Afghanistan  2001         371.2675
# 2                                 Afghanistan  2002         447.8971
# 3                                 Afghanistan  2003         463.6655
# 4                                 Afghanistan  2004         465.8062
# ...                                       ...   ...              ...
# 4174           Svalbard and Jan Mayen Islands  2016           0.0000
# 4175           Svalbard and Jan Mayen Islands  2017           0.0000
# 4176           Svalbard and Jan Mayen Islands  2018           0.0000
# 4177           Svalbard and Jan Mayen Islands  2019           0.0000
# 4178           Svalbard and Jan Mayen Islands  2020           0.0000
#
# emission_type  Emissions (CO2)  Emissions (CO2eq) (AR5)  \
# 0                   -1474.8030               13346.3010
# ...

# %%
emissions_pivot_df = emissions_pivot_df.rename(columns={'Emissions (CH4)':'Emissions_CH4', 'Emissions (CO2)':'Emissions_CO2', 'Emissions (CO2eq) (AR5)': 'Emissions_CO2eq_AR5', \
    'Emissions (CO2eq) from CH4 (AR5)': 'Emissions_CO2eq_from_CH4_AR5', 'Emissions (CO2eq) from F-gases (AR5)': 'Emissions_CO2eq_from_F-gases_AR5',\
        'Emissions (CO2eq) from N2O (AR5)':'Emissions_CO2eq_from_N2O_AR5', 'Emissions (N2O)':'Emissions_N2O'})

# %%
emissions_pivot_df['area'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        "C?e d'Ivoire", 'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada',
#        'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'China, Taiwan Province of', 'China, mainland',
#        'Colombia', 'Comoros', 'Congo', 'Cook Islands', 'Costa Rica',
#        'Croatia', 'Cuba', 'Cyprus', 'Czechia',
#        "Democratic People's Republic of Korea",
# ...

# %%
north_korea_df = emissions_pivot_df.loc[emissions_pivot_df['area']=="Democratic People's Republic of Korea"]

# %%
germany_df = emissions_pivot_df.loc[emissions_pivot_df['area']=="Germany"]

# %%
china_df = emissions_pivot_df.loc[emissions_pivot_df['area']=='China']

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(emissions_pivot_df.year, emissions_pivot_df.Emissions_CH4)
plt.xticks(np.arange(2000, 2021, 1), rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x292e2cb1e88>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
emissions_pivot_df.to_csv("emissions_pivot_df.csv")

# %%
plt.scatter(china_df.year, china_df.Emissions_CH4)
plt.xticks(np.arange(2000, 2021, 1), rotation=90)
plt.title('china')
# Out:
# Text(0.5, 1.0, 'china')

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
plt.scatter(china_df.year, china_df.Emissions_CH4)
plt.xticks(np.arange(2000, 2021, 1), rotation=90)
plt.title('china emissions')
plt.xlabel('Years')
plt.ylabel('CH4 Emissions (kilotons)')
# Out:
# Text(0, 0.5, 'CH4 Emissions (kilotons)')

# %%
X = china_df.year.values.reshape(-1,1)

# %%
y = china_df.Emissions_CH4

# %%
model = LinearRegression()
model.fit(X,y)
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (21,)

# %%
plt.scatter(X,y)
plt.plot(X, y_pred, color='red')
plt.xticks(np.arange(2000, 2021, 1), rotation=90)
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [1072.73362623]
# -2103840.462248917
